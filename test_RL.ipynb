# %%
import matplotlib.pyplot as plt
from train import *
# Out:
# 2023-11-07 19:31:42.967095: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-07 19:31:43.263477: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-11-07 19:31:43.263500: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
history = train(reward_target=100.0, realtime_render=True)
# Out:
# Finished episode 10 Average rewards:  33.4
# Finished episode 20 Average rewards:  51.4
# Finished episode 30 Average rewards:  76.9
# Finished episode 40 Average rewards:  88.0
# Finished episode 50 Average rewards:  182.7

# %%
plt.figure(figsize=(10,5))
plt.plot(history)
plt.xlabel('Epsiode')
plt.ylabel('Collected rewards')
plt.show()

# %%
export(history)
